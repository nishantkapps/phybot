# %%
import matplotlib.pyplot as plt

# %%
x= [643.76025947, 645.07999712, 654.08988158, 654.33876547, 650.98126689,
 662.15573516, 652.09443664, 645.89371159, 649.57884582, 628.9370762,
 623.52822591, 657.71050091, 662.19024732, 645.50970619, 606.48620861,
 582.01327578, 636.10619852, 659.60678182, 714.31892908, 617.99745109,
 592.2341233, 651.01477325, 647.82676286, 656.60319511, 569.13702282,
 545.83477555]

# %%
y= [1122.07512161, 1073.16380898, 958.95679814, 834.81519712, 743.75972042,
  626.31688147, 858.26591964, 839.73265543, 986.8076424, 1170.67029972,
 1268.14640401, 866.95934461, 876.65896886, 1015.13723522, 1162.27000962,
 1238.3511559, 1120.64037722, 1410.02503388, 1712.36503072, 1756.64687905,
 1756.8465904, 1123.43497136, 1394.94496215, 1667.09659132, 1706.50497219,
 1706.19208203]

# %%
plt.scatter(x, y, c='red', s=30)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
pm = np.load('3d_joints/Ex1/PM_001-120fps.npy')

# %%
len(pm)
# Out:
# 12063

# %%
frame = 11000

# %%
x_data = pm[frame][:,0]
y_data = pm[frame][:,1]
z_data = pm[frame][:,2]

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x_data, y_data, z_data, c='blue', marker='o', s=50)
plt.show()
